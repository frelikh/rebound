# %%
import numpy as np
from matplotlib import pyplot as plt
infile = "/Users/renata/sftp_graymalkin/semimajor_axis_file.txt"

# %%
time,a,particle = np.loadtxt(infile,unpack=True)

# %%
# %matplotlib inline

# %%
[plt.scatter(time[i::10],a[i::10],label=i,s=1) for i in range(10)]
plt.legend(loc=1)
plt.ylim(0,15)
plt.xlim(5000,6500)
# Out:
# (5000, 6500)
